# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926747950","type":"CreateEvent","actor":{"id":181552874,"login":"oha99","display_login":"oha99","gravatar_id":"","url":"https://api.github.com/users/oha99","avatar_url":"https://avatars.githubusercontent.com/u/181552874?"},"repo":{"id":857267110,"name":"oha99/My-Profiles","url":"https://api.github.com/repos/oha99/My-Profiles"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2024-09-14T07:41:41Z"},{"id":"41926747945","type":"PushEvent","actor":{"id":121993898,"login":"APieceOfToast123","display_login":"APieceOfToast123","gravatar_id":"","url":"https://api.github.com/users/APieceOfToast123","avatar_url":"https://avatars.githubusercontent.com/u/121993898?"},"repo":{"id":852667669,"name":"APieceOfToast123/nuxtjs-tailwindcss-portfolio","url":"https://api.github.com/repos/APieceOfToast123/nuxtjs-tailwindcss-portfolio"},"payload":{"repository_id":852667669,"push_id":20235284904,"size":1,"disti
# ...
